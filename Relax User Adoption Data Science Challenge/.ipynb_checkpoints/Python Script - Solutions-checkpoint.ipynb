# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime  
from datetime import timedelta

# %% [markdown]
# # Import user engagement data:

# %%
user_engagement_data=pd.read_csv("takehome_user_engagement.csv")

# %%
user_data=pd.read_csv("takehome_users.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # Data Description:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Here's the definition of the "Adopted User":
# Defining   an      "adopted   user"      as   a   user   who         has   logged   into   the   product   on   three   separate  days   in   at   least   one   seven­day   period  ,   identify   which   factors   predict   future   user  adoption  .

# %%
user_data.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# 2                         0                           0      94
# 3                         0                           0       1
# 4                         0                           0     193
#
#    invited_by_user_id
# 0             10803.0
# 1               316.0
# 2              1525.0
# 3              5151.0
# 4              5240.0

# %%
user_engagement_data.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %% [markdown]
# # Identify the adopted user versus the non-adopted user:

# %%
def func_return_week_starting_Sunday(date_input1):
    if pd.to_datetime(date_input1).weekday()==6:
        return pd.to_datetime(date_input1)
    if pd.to_datetime(date_input1).weekday()!=6:
        return pd.to_datetime(pd.to_datetime(date_input1)+timedelta(days=7-pd.to_datetime(date_input1).weekday()-8))

# %%
user_engagement_data['Week_starting_sunday']=user_engagement_data['time_stamp'].apply(func_return_week_starting_Sunday)

# %%
weekly_sessions_by_user=user_engagement_data.groupby(['user_id', 'Week_starting_sunday'])['visited'].sum().reset_index()

# %%
max_weekly_sessions_by_user=weekly_sessions_by_user.groupby('user_id')['visited'].max()

# %%
Adopted_user_id_list=list(max_weekly_sessions_by_user[max_weekly_sessions_by_user>=3].index)

# %% [markdown]
# # Add a user_adoption flag in the user data set and mark the adopted user in the dataset:

# %%
user_data['User_adoption_flag']=user_data['object_id'].apply(lambda x: x in Adopted_user_id_list)
user_data['User_adoption_flag']=user_data['User_adoption_flag'].astype(int)

# %%
user_data['User_adoption_flag'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # Create three fields: total login counts in the first 30 days after signing up, Weekly logins (usage frequency), weekly logins (usage frequency) for the first 30 days.

# %%
user_data_copy=user_data.copy()

# %% [markdown]
# Create a field called "30 days after account creation" within user_data data frame

# %%
user_data_copy.creation_time=pd.to_datetime(user_data_copy.creation_time)
user_data_copy['30_days_after_account_creation']=user_data_copy.creation_time + timedelta(days=30)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
user_data_copy.to_sql('user_data', con=engine, if_exists='replace')
user_engagement_data.to_sql('user_engagement_data', con=engine, if_exists='replace')

# %%
df_30_days_before_account_creation_activity=engine.execute("SELECT b.* FROM user_data a inner join user_engagement_data b on a.creation_time and b.time_stamp <= a.`30_days_after_account_creation` and a.object_id=b.user_id ").fetchall()

# %%
df_30_days_before_account_creation_activity=pd.DataFrame(df_30_days_before_account_creation_activity)[[1,2,3,4]]

# %%
df_30_days_before_account_creation_activity.columns=['Timestamp', 'user_id', 'Sessions', 'Week']

# %% [markdown]
# Get the total number of sessions by user for the first 30 days of account creation:

# %%
total_user_sessions_first_30_days=df_30_days_before_account_creation_activity.groupby('user_id')['Sessions'].sum()

# %% [markdown]
# Get the average weekly session by user for the first 30 days:

# %%
average_weekly_user_sessions_first_30_days=df_30_days_before_account_creation_activity.groupby(['user_id', 'Week'])['Sessions'].sum().reset_index().groupby('user_id')['Sessions'].mean()

# %% [markdown]
# Get the average weekly sessions over time:

# %%
average_weekly_sessions_over_time=weekly_sessions_by_user.groupby('user_id')['visited'].mean()

# %% [markdown]
# Merge the newly created user activity session fields with the user data:

# %%
user_data_copy.set_index('object_id', inplace=True)

# %%
average_weekly_sessions_over_time=pd.DataFrame(average_weekly_sessions_over_time, columns=['average_weekly_sessions_over_time'])

# %%
average_weekly_user_sessions_first_30_days=pd.DataFrame(average_weekly_user_sessions_first_30_days, columns=['average_weekly_user_sessions_first_30_days'])

# %%
total_user_sessions_first_30_days=pd.DataFrame(total_user_sessions_first_30_days, columns=['total_user_sessions_first_30_days'])

# %%
total_user_sessions_first_30_days
# Out:
# Empty DataFrame
# Columns: [total_user_sessions_first_30_days]
# Index: []

# %%
pd.merge(pd.merge(pd.merge(user_data_copy, pd.DataFrame(average_weekly_sessions_over_time), how='left',left_index=True, right_index=True), pd.DataFrame(average_weekly_user_sessions_first_30_days), left_index=True, right_index=True, how='left'), pd.DataFrame(total_user_sessions_first_30_days), left_index=True, right_index=True, how='left')
# Out:
#                 creation_time                 name  \
# object_id
# 1         2014-04-22 03:53:30       Clausen August
# 2         2013-11-15 03:45:04        Poole Matthew
# 3         2013-03-19 23:14:52    Bottrill Mitchell
# 4         2013-05-21 08:09:28      Clausen Nicklas
# 5         2013-01-17 10:14:20            Raw Grace
# 6         2013-12-17 03:37:06        Cunha Eduardo
# 7         2012-12-16 13:24:32         Sewell Tyler
# 8         2013-07-31 05:34:02    Hamilton Danielle
# 9         2013-11-05 04:04:24           Amsel Paul
# 10        2013-01-16 22:08:03         Santos Carla
# 11        2013-12-26 03:55:54       Paulsen Malthe
# 12        2014-04-17 23:48:38      Mathiesen Lærke
# 13        2014-03-30 16:19:38        Fry Alexander
# 14        2012-10-11 16:14:33          Rivera Bret
# 15        2013-07-16 21:33:54          Theiss Ralf
# 16        2013-02-11 10:09:50           Engel René
# 17        2014-04-09 14:39:38     Reynolds Anthony
# 18        2013-08-24 00:26:46     Gregersen Celina
# 19        2013-05-24 14:56:36       Collins Arlene
# 20        2014-03-06 11:46:38        Helms Mikayla
# 21        2013-01-22 12:27:42         Hunter Alfie
# 22        2014-02-10 06:00:46         Myers Jordan
# 23        2012-08-17 08:30:27          Souza Alice
# 24        2013-09-09 22:20:03       Woodruff James
# 25        2014-02-25 00:11:13          Stone Elise
# 26        2013-07-28 00:53:32       Wexler Florian
# 27        2014-01-14 17:35:11          Santos Luís
# 28        2013-02-11 20:00:25    Weissmuller Marko
# 29        2013-09-16 02:08:41     Fernandes Evelyn
# 30        2013-06-04 00:44:25           Egger Leah
# ...                       ...                  ...
# 11971     2013-05-04 06:54:23    Ferreira Beatrice
# 11972     2012-09-13 23:23:11      Penington Jamie
# 11973     2012-10-30 03:09:47       Simmons Thomas
# 11974     2012-12-26 16:42:08          Scott James
# 11975     2013-03-23 11:10:11       Daecher Jürgen
# 11976     2013-12-25 22:01:41            Kohl Leah
# 11977     2013-09-17 18:58:51         Crary Joshua
# 11978     2014-04-23 16:28:06         Castro Pedro
# 11979     2013-01-28 09:26:33         Hurst Harley
# 11980     2014-02-02 15:23:18  Gloeckner Franziska
# 11981     2013-03-05 01:53:48            Fry Tyler
# 11982     2013-12-06 14:39:15        Barajas Maria
# 11983     2013-07-30 00:23:36           Engel Mike
# 11984     2014-02-11 21:26:11           Reed Cerys
# 11985     2013-07-08 17:23:26     Jespersen Marcus
# 11986     2012-06-24 01:02:14        Ribeiro Clara
# 11987     2013-03-15 03:21:01           Reed Poppy
# 11988     2014-03-15 11:04:47          Minick John
# 11989     2013-09-02 11:24:33       Pereira Emilly
# 11990     2013-07-05 21:00:48            Juhl Aase
# 11991     2014-04-20 14:22:45        Vaughn Arthur
# 11992     2014-04-09 19:39:56     Hermansen Amanda
# 11993     2013-03-28 23:24:21      Townsend Isabel
# 11994     2012-06-05 04:46:16       Grimstone Joel
# 11995     2013-10-21 13:33:17     Werfel Sebastian
# 11996     2013-09-06 06:14:15         Meier Sophia
# 11997     2013-01-10 18:28:37        Fisher Amelie
# 11998     2014-04-27 12:45:16          Haynes Jake
# 11999     2012-05-31 11:55:59         Faber Annett
# 12000     2014-01-26 08:57:12           Lima Thaís
#
#                                          email     creation_source  \
# object_id
# 1                     AugustCClausen@yahoo.com        GUEST_INVITE
# 2                       MatthewPoole@gustr.com          ORG_INVITE
# 3                   MitchellBottrill@gustr.com          ORG_INVITE
# 4                    NicklasSClausen@yahoo.com        GUEST_INVITE
# 5                           GraceRaw@yahoo.com        GUEST_INVITE
# 6                EduardoPereiraCunha@yahoo.com        GUEST_INVITE
# 7                   TylerSewell@jourrapide.com              SIGNUP
# 8                   DanielleHamilton@yahoo.com   PERSONAL_PROJECTS
# 9                        PaulAmsel@hotmail.com   PERSONAL_PROJECTS
# 10               CarlaFerreiraSantos@gustr.com          ORG_INVITE
# 11                    MaltheAPaulsen@gustr.com              SIGNUP
# 12                   LaerkeLMathiesen@cuvox.de          ORG_INVITE
# 13                      AlexanderDFry@cuvox.de          ORG_INVITE
# 14                       BretKRivera@gmail.com              SIGNUP
# 15                      RalfTheiss@hotmail.com   PERSONAL_PROJECTS
# 16                       ReneEngel@hotmail.com   PERSONAL_PROJECTS
# 17              AnthonyReynolds@jourrapide.com        GUEST_INVITE
# 18             CelinaAGregersen@jourrapide.com        GUEST_INVITE
# 19                    ArleneRCollins@gmail.com              SIGNUP
# 20                          lqyvjilf@uhzdq.com              SIGNUP
# 21                       AlfieHunter@gmail.com   PERSONAL_PROJECTS
# 22                       JordanMyers@gmail.com          ORG_INVITE
# 23                  AliceAraujoSouza@gustr.com          ORG_INVITE
# 24                     JamesTWoodruff@cuvox.de              SIGNUP
# 25                   EliseStone@jourrapide.com        GUEST_INVITE
# 26                FlorianWexler@jourrapide.com          ORG_INVITE
# 27                   LuisPintoSantos@gmail.com          ORG_INVITE
# 28             MarkoWeissmuller@jourrapide.com              SIGNUP
# 29         EvelynSousaFernandes@jourrapide.com              SIGNUP
# 30                    LeahEgger@jourrapide.com        GUEST_INVITE
# ...                                        ...                 ...
# 11971        BeatriceBarbosaFerreira@yahoo.com        GUEST_INVITE
# 11972                 JamiePenington@yahoo.com          ORG_INVITE
# 11973                  ThomasSimmons@gmail.com   PERSONAL_PROJECTS
# 11974                    JamesJScott@gmail.com              SIGNUP
# 11975                  JurgenDaecher@gustr.com        GUEST_INVITE
# 11976                     LeahKohl@hotmail.com   PERSONAL_PROJECTS
# 11977                   JoshuaHCrary@gmail.com  SIGNUP_GOOGLE_AUTH
# 11978               PedroCunhaCastro@gustr.com   PERSONAL_PROJECTS
# 11979                    HarleyHurst@yahoo.com              SIGNUP
# 11980                       ljnnbqdr@cgbld.com          ORG_INVITE
# 11981                       TylerFry@gmail.com        GUEST_INVITE
# 11982                  MariaCBarajas@gmail.com          ORG_INVITE
# 11983                      MikeEngel@gmail.com  SIGNUP_GOOGLE_AUTH
# 11984                      CerysReed@yahoo.com              SIGNUP
# 11985                MarcusTJespersen@cuvox.de   PERSONAL_PROJECTS
# 11986             ClaraBarrosRibeiro@gmail.com  SIGNUP_GOOGLE_AUTH
# 11987                       ftdkorrj@uyhoy.com              SIGNUP
# 11988                    JohnFMinick@yahoo.com   PERSONAL_PROJECTS
# 11989          EmillyOliveiraPereira@gmail.com  SIGNUP_GOOGLE_AUTH
# 11990                 AasePJuhl@jourrapide.com          ORG_INVITE
# 11991                  ArthurJVaughn@gmail.com  SIGNUP_GOOGLE_AUTH
# 11992               AmandaAHermansen@yahoo.com   PERSONAL_PROJECTS
# 11993                  IsabelTownsend@cuvox.de   PERSONAL_PROJECTS
# 11994                       conxzghp@eaouk.com        GUEST_INVITE
# 11995                SebastianWerfel@gmail.com   PERSONAL_PROJECTS
# 11996                    SophiaMeier@gustr.com          ORG_INVITE
# 11997                   AmelieFisher@gmail.com  SIGNUP_GOOGLE_AUTH
# 11998                      JakeHaynes@cuvox.de        GUEST_INVITE
# 11999                       mhaerzxp@iuxiw.com   PERSONAL_PROJECTS
# 12000                ThaisMeloLima@hotmail.com              SIGNUP
#
#            last_session_creation_time  opted_in_to_mailing_list  \
# object_id
# 1                        1.398139e+09                         1
# 2                        1.396238e+09                         0
# 3                        1.363735e+09                         0
# 4                        1.369210e+09                         0
# 5                        1.358850e+09                         0
# 6                        1.387424e+09                         0
# 7                        1.356010e+09                         0
# 8                                 NaN                         1
# 9                                 NaN                         0
# 10                       1.401833e+09                         1
# 11                       1.388117e+09                         0
# 12                                NaN                         0
# 13                       1.396196e+09                         0
# 14                       1.350058e+09                         0
# 15                                NaN                         0
# 16                                NaN                         0
# 17                       1.397314e+09                         1
# 18                                NaN                         0
# 19                       1.369926e+09                         1
# 20                       1.401364e+09                         0
# 21                       1.358858e+09                         0
# 22                       1.392012e+09                         0
# 23                       1.345279e+09                         1
# 24                       1.378765e+09                         1
# 25                       1.393373e+09                         1
# 26                                NaN                         0
# 27                       1.389807e+09                         0
# 28                       1.360872e+09                         0
# 29                       1.379384e+09                         0
# 30                       1.370307e+09                         0
# ...                               ...                       ...
# 11971                             NaN                         0
# 11972                             NaN                         0
# 11973                             NaN                         0
# 11974                    1.356713e+09                         0
# 11975                    1.400757e+09                         1
# 11976                             NaN                         0
# 11977                    1.379704e+09                         0
# 11978                             NaN                         1
# 11979                    1.359624e+09                         0
# 11980                    1.397835e+09                         0
# 11981                    1.364868e+09                         0
# 11982                    1.386341e+09                         1
# 11983                    1.375144e+09                         0
# 11984                    1.392154e+09                         0
# 11985                             NaN                         0
# 11986                    1.341105e+09                         0
# 11987                    1.363318e+09                         0
# 11988                    1.401621e+09                         0
# 11989                    1.378553e+09                         1
# 11990                    1.373144e+09                         0
# 11991                    1.401460e+09                         0
# 11992                    1.397245e+09                         0
# 11993                             NaN                         0
# 11994                             NaN                         0
# 11995                    1.382449e+09                         0
# 11996                    1.378448e+09                         0
# 11997                    1.358275e+09                         0
# 11998                    1.398603e+09                         1
# 11999                    1.338638e+09                         0
# 12000                    1.390727e+09                         0
#
#            enabled_for_marketing_drip  org_id  invited_by_user_id  \
# object_id
# 1                                   0      11             10803.0
# 2                                   0       1               316.0
# 3                                   0      94              1525.0
# 4                                   0       1              5151.0
# 5                                   0     193              5240.0
# 6                                   0     197             11241.0
# 7                                   1      37                 NaN
# 8                                   1      74                 NaN
# 9                                   0     302                 NaN
# 10                                  1     318              4143.0
# 11                                  0      69                 NaN
# 12                                  0     130              9270.0
# 13                                  0     254             11204.0
# 14                                  0       0                 NaN
# 15                                  0     175                 NaN
# 16                                  0     211                 NaN
# 17                                  0     175              1600.0
# 18                                  0       2              3153.0
# 19                                  0       0                 NaN
# 20                                  0      58                 NaN
# 21                                  0      54                 NaN
# 22                                  0       7              2994.0
# 23                                  0       6                23.0
# 24                                  0     123                 NaN
# 25                                  0      81              6312.0
# 26                                  0      56             11857.0
# 27                                  0     134              4189.0
# 28                                  0       6                 NaN
# 29                                  0      92                 NaN
# 30                                  0     251              4835.0
# ...                               ...     ...                 ...
# 11971                               0       3             11854.0
# 11972                               0      16              7012.0
# 11973                               0      52                 NaN
# 11974                               0     167                 NaN
# 11975                               0      31              6410.0
# 11976                               0     248                 NaN
# 11977                               0     144                 NaN
# 11978                               0      29                 NaN
# 11979                               0       2                 NaN
# 11980                               0     406              3068.0
# 11981                               0     110              5775.0
# 11982                               1      57              2527.0
# 11983                               0     234                 NaN
# 11984                               0     170                 NaN
# 11985                               0      74                 NaN
# 11986                               0     111                 NaN
# 11987                               0       1                 NaN
# 11988                               0     114                 NaN
# 11989                               0      22                 NaN
# 11990                               0      25              3944.0
# 11991                               0     388                 NaN
# 11992                               0     129                 NaN
# 11993                               0     281                 NaN
# 11994                               0      84              5450.0
# 11995                               0       0                 NaN
# 11996                               0      89              8263.0
# 11997                               0     200                 NaN
# 11998                               1      83              8074.0
# 11999                               0       6                 NaN
# 12000                               1       0                 NaN
#
#            User_adoption_flag 30_days_after_account_creation  \
# object_id
# 1                           0            2014-05-22 03:53:30
# 2                           0            2013-12-15 03:45:04
# 3                           0            2013-04-18 23:14:52
# 4                           0            2013-06-20 08:09:28
# 5                           0            2013-02-16 10:14:20
# 6                           0            2014-01-16 03:37:06
# 7                           0            2013-01-15 13:24:32
# 8                           0            2013-08-30 05:34:02
# 9                           0            2013-12-05 04:04:24
# 10                          1            2013-02-15 22:08:03
# 11                          0            2014-01-25 03:55:54
# 12                          0            2014-05-17 23:48:38
# 13                          0            2014-04-29 16:19:38
# 14                          0            2012-11-10 16:14:33
# 15                          0            2013-08-15 21:33:54
# 16                          0            2013-03-13 10:09:50
# 17                          0            2014-05-09 14:39:38
# 18                          0            2013-09-23 00:26:46
# 19                          0            2013-06-23 14:56:36
# 20                          1            2014-04-05 11:46:38
# 21                          0            2013-02-21 12:27:42
# 22                          0            2014-03-12 06:00:46
# 23                          0            2012-09-16 08:30:27
# 24                          0            2013-10-09 22:20:03
# 25                          0            2014-03-27 00:11:13
# 26                          0            2013-08-27 00:53:32
# 27                          0            2014-02-13 17:35:11
# 28                          0            2013-03-13 20:00:25
# 29                          0            2013-10-16 02:08:41
# 30                          0            2013-07-04 00:44:25
# ...                       ...                            ...
# 11971                       0            2013-06-03 06:54:23
# 11972                       0            2012-10-13 23:23:11
# 11973                       0            2012-11-29 03:09:47
# 11974                       0            2013-01-25 16:42:08
# 11975                       1            2013-04-22 11:10:11
# 11976                       0            2014-01-24 22:01:41
# 11977                       0            2013-10-17 18:58:51
# 11978                       0            2014-05-23 16:28:06
# 11979                       0            2013-02-27 09:26:33
# 11980                       0            2014-03-04 15:23:18
# 11981                       0            2013-04-04 01:53:48
# 11982                       0            2014-01-05 14:39:15
# 11983                       0            2013-08-29 00:23:36
# 11984                       0            2014-03-13 21:26:11
# 11985                       0            2013-08-07 17:23:26
# 11986                       0            2012-07-24 01:02:14
# 11987                       0            2013-04-14 03:21:01
# 11988                       1            2014-04-14 11:04:47
# 11989                       0            2013-10-02 11:24:33
# 11990                       0            2013-08-04 21:00:48
# 11991                       0            2014-05-20 14:22:45
# 11992                       0            2014-05-09 19:39:56
# 11993                       0            2013-04-27 23:24:21
# 11994                       0            2012-07-05 04:46:16
# 11995                       0            2013-11-20 13:33:17
# 11996                       0            2013-10-06 06:14:15
# 11997                       0            2013-02-09 18:28:37
# 11998                       0            2014-05-27 12:45:16
# 11999                       0            2012-06-30 11:55:59
# 12000                       0            2014-02-25 08:57:12
#
#           average_weekly_sessions_over_time  \
# object_id
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# ...                                     ...
# 11971                                   NaN
# 11972                                   NaN
# 11973                                   NaN
# 11974                                   NaN
# 11975                                   NaN
# 11976                                   NaN
# 11977                                   NaN
# 11978                                   NaN
# 11979                                   NaN
# 11980                                   NaN
# 11981                                   NaN
# 11982                                   NaN
# 11983                                   NaN
# 11984                                   NaN
# 11985                                   NaN
# 11986                                   NaN
# 11987                                   NaN
# 11988                                   NaN
# 11989                                   NaN
# 11990                                   NaN
# 11991                                   NaN
# 11992                                   NaN
# 11993                                   NaN
# 11994                                   NaN
# 11995                                   NaN
# 11996                                   NaN
# 11997                                   NaN
# 11998                                   NaN
# 11999                                   NaN
# 12000                                   NaN
#
#           average_weekly_user_sessions_first_30_days  \
# object_id
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# ...                                              ...
# 11971                                            NaN
# 11972                                            NaN
# 11973                                            NaN
# 11974                                            NaN
# 11975                                            NaN
# 11976                                            NaN
# 11977                                            NaN
# 11978                                            NaN
# 11979                                            NaN
# 11980                                            NaN
# 11981                                            NaN
# 11982                                            NaN
# 11983                                            NaN
# 11984                                            NaN
# 11985                                            NaN
# 11986                                            NaN
# 11987                                            NaN
# 11988                                            NaN
# 11989                                            NaN
# 11990                                            NaN
# 11991                                            NaN
# 11992                                            NaN
# 11993                                            NaN
# 11994                                            NaN
# 11995                                            NaN
# 11996                                            NaN
# 11997                                            NaN
# 11998                                            NaN
# 11999                                            NaN
# 12000                                            NaN
#
#           total_user_sessions_first_30_days
# object_id
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# ...                                     ...
# 11971                                   NaN
# 11972                                   NaN
# 11973                                   NaN
# 11974                                   NaN
# 11975                                   NaN
# 11976                                   NaN
# 11977                                   NaN
# 11978                                   NaN
# 11979                                   NaN
# 11980                                   NaN
# 11981                                   NaN
# 11982                                   NaN
# 11983                                   NaN
# 11984                                   NaN
# 11985                                   NaN
# 11986                                   NaN
# 11987                                   NaN
# 11988                                   NaN
# 11989                                   NaN
# 11990                                   NaN
# 11991                                   NaN
# 11992                                   NaN
# 11993                                   NaN
# 11994                                   NaN
# 11995                                   NaN
# 11996                                   NaN
# 11997                                   NaN
# 11998                                   NaN
# 11999                                   NaN
# 12000                                   NaN
#
# [12000 rows x 14 columns]

# %% [markdown]
# # Exploratory Analysis on the dataset
